# %%
# %cd ..
# Out:
# /Users/raiota/git/github.com/raiota/RCGA

# %%
from ga_tools import *
from benchmarks import *

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import ArtistAnimation

# %% [markdown]
# # Optimize Example and Sample Usage
#
# ## Ackley function

# %%
GEN = 1000
N_DIM = 10
G_MIN = -32
G_MAX = 32
POP_SIZE = 300
PARENT_NUM = 50
CHILD_NUM = 200

EVALTYPE = alternation.evalType.MINIMIZE
CROSSTYPE = crossover.crossoverType.E_UNDX
RANDOMTYPE = crossover.randomType.UNIFORM

# %%
# object for JGG alternation
pop = alternation.JGG(dim=N_DIM,
                      evaluation_func=ackley, evaluation_type=EVALTYPE,
                      gene_min=G_MIN, gene_max=G_MAX,
                      crossover_type=CROSSTYPE,
                      random_type=RANDOMTYPE,
                      pop_size=POP_SIZE, parent_num=PARENT_NUM, child_num=CHILD_NUM,
                      seed=64)

# make initial population
pop.init_population()

# evaluate initial population
pop.eval()

# %%
generation = []
stats_min = []
stats_max = []
stats_ave = []

generation.append(0)
stats_min.append(numpy.min([ind.fitness for ind in pop.population]))
stats_max.append(numpy.max([ind.fitness for ind in pop.population]))
stats_ave.append(numpy.average([ind.fitness for ind in pop.population]))

print("* Generation 0 is fin. the minimum value is {}".format(stats_min[0]))

for i in range(GEN):
    pop.generation_step()
    
    generation.append(i+1)
    stats_min.append(numpy.min([ind.fitness for ind in pop.population]))
    stats_max.append(numpy.max([ind.fitness for ind in pop.population]))
    stats_ave.append(numpy.average([ind.fitness for ind in pop.population]))
    
    print("* Generation {0} is fin. the minimum value is {1}".format(generation[i+1], stats_min[i+1]))
# Out:
# * Generation 0 is fin. the minimum value is 18.325515087418417
# * Generation 1 is fin. the minimum value is 15.509115442943203
# * Generation 2 is fin. the minimum value is 15.509115442943203
# * Generation 3 is fin. the minimum value is 13.335391381160115
# * Generation 4 is fin. the minimum value is 12.116334556769079
# * Generation 5 is fin. the minimum value is 9.126128077920818
# * Generation 6 is fin. the minimum value is 8.597123635326685
# * Generation 7 is fin. the minimum value is 8.597123635326685
# * Generation 8 is fin. the minimum value is 8.597123635326685
# * Generation 9 is fin. the minimum value is 8.979273920959365
# * Generation 10 is fin. the minimum value is 8.979273920959365
# * Generation 11 is fin. the minimum value is 8.979273920959365
# * Generation 12 is fin. the minimum value is 7.661922745446526
# * Generation 13 is fin. the minimum value is 7.661922745446526
# * Generation 14 is fin. the minimum value is 7.392868337061884
# * Generation 15 is fin. the minimum value is 6.481782877080569
# * Generation 16 is fin. the minimum value is 5.72876933594843
# * Generation 17 is fin. the minimum value is 5.72876933594843
# * Generation 18 is fin. the minimum value is 5.72876933594843
# * Generation 19 is fin. the minimum value is 5.709549942037887
# * Generation 20 is fin. the minimum value is 4.539822648157977
# * Generation 21 is fin. the minimum value is 3.758905804218084
# * Generation 22 is fin. the minimum value is 3.758905804218084
# * Generation 23 is fin. the minimum value is 3.758905804218084
# * Generation 24 is fin. the minimum value is 3.758905804218084
# * Generation 25 is fin. the minimum value is 3.900672067708407
# * Generation 26 is fin. the minimum value is 3.8731293503903728
# * Generation 27 is fin. the minimum value is 2.5698762844405145
# * Generation 28 is fin. the minimum value is 2.5698762844405145
# * Generation 29 is fin. the minimum value is 2.5698762844405145
# * Generation 30 is fin. the minimum value is 2.5698762844405145
# * Generation 31 is fin. the minimum value is 2.5698762844405145
# * Generation 32 is fin. the minimum value is 2.28379319849733
# * Generation 33 is fin. the minimum value is 2.28379319849733
# * Generation 34 is fin. the minimum value is 2.28379319849733
# * Generation 35 is fin. the minimum value is 2.28379319849733
# * Generation 36 is fin. the minimum value is 2.145834819325292
# * Generation 37 is fin. the minimum value is 2.145834819325292
# * Generation 38 is fin. the minimum value is 2.145834819325292
# * Generation 39 is fin. the minimum value is 2.145834819325292
# * Generation 40 is fin. the minimum value is 1.8262393480547687
# * Generation 41 is fin. the minimum value is 1.647934078982554
# * Generation 42 is fin. the minimum value is 1.647934078982554
# * Generation 43 is fin. the minimum value is 1.4013797332647115
# * Generation 44 is fin. the minimum value is 1.4013797332647115
# * Generation 45 is fin. the minimum value is 1.4013797332647115
# * Generation 46 is fin. the minimum value is 1.1320687456418774
# * Generation 47 is fin. the minimum value is 1.1320687456418774
# * Generation 48 is fin. the minimum value is 1.1320687456418774
# * Generation 49 is fin. the minimum value is 1.1320687456418774
# * Generation 50 is fin. the minimum value is 0.6406438720629781
# * Generation 51 is fin. the minimum value is 0.6406438720629781
# * Generation 52 is fin. the minimum value is 0.6406438720629781
# * Generation 53 is fin. the minimum value is 0.6406438720629781
# * Generation 54 is fin. the minimum value is 0.6406438720629781
# * Generation 55 is fin. the minimum value is 0.5274888800309445
# * Generation 56 is fin. the minimum value is 0.3863495694528245
# * Generation 57 is fin. the minimum value is 0.3863495694528245
# * Generation 58 is fin. the minimum value is 0.3863495694528245
# * Generation 59 is fin. the minimum value is 0.3863495694528245
# * Generation 60 is fin. the minimum value is 0.34633255720617173
# * Generation 61 is fin. the minimum value is 0.503285219686338
# * Generation 62 is fin. the minimum value is 0.2765685873288639
# * Generation 63 is fin. the minimum value is 0.2765685873288639
# * Generation 64 is fin. the minimum value is 0.2765685873288639
# * Generation 65 is fin. the minimum value is 0.17518990769376241
# * Generation 66 is fin. the minimum value is 0.17518990769376241
# * Generation 67 is fin. the minimum value is 0.17518990769376241
# * Generation 68 is fin. the minimum value is 0.17518990769376241
# * Generation 69 is fin. the minimum value is 0.19461845000796663
# * Generation 70 is fin. the minimum value is 0.17604629380987724
# * Generation 71 is fin. the minimum value is 0.17452406467613057
# * Generation 72 is fin. the minimum value is 0.16389620769449031
# * Generation 73 is fin. the minimum value is 0.14518433669195918
# * Generation 74 is fin. the minimum value is 0.1051747443571367
# * Generation 75 is fin. the minimum value is 0.1051747443571367
# * Generation 76 is fin. the minimum value is 0.1051747443571367
# * Generation 77 is fin. the minimum value is 0.07304273894378754
# * Generation 78 is fin. the minimum value is 0.07304273894378754
# * Generation 79 is fin. the minimum value is 0.06801798983711249
# * Generation 80 is fin. the minimum value is 0.06801798983711249
# * Generation 81 is fin. the minimum value is 0.06418040361740296
# * Generation 82 is fin. the minimum value is 0.06418040361740296
# * Generation 83 is fin. the minimum value is 0.06801798983711249
# * Generation 84 is fin. the minimum value is 0.06295951020876789
# * Generation 85 is fin. the minimum value is 0.06090291426679828
# * Generation 86 is fin. the minimum value is 0.06069424727064021
# * Generation 87 is fin. the minimum value is 0.054100516958078604
# * Generation 88 is fin. the minimum value is 0.04653043736732032
# * Generation 89 is fin. the minimum value is 0.03960603598736645
# * Generation 90 is fin. the minimum value is 0.03411772603769947
# * Generation 91 is fin. the minimum value is 0.03411772603769947
# * Generation 92 is fin. the minimum value is 0.03411772603769947
# * Generation 93 is fin. the minimum value is 0.03411772603769947
# * Generation 94 is fin. the minimum value is 0.028047841954777386
# * Generation 95 is fin. the minimum value is 0.02711613284081471
# * Generation 96 is fin. the minimum value is 0.02711613284081471
# * Generation 97 is fin. the minimum value is 0.02685671371081888
# * Generation 98 is fin. the minimum value is 0.021425364803019153
# * Generation 99 is fin. the minimum value is 0.021425364803019153
# * Generation 100 is fin. the minimum value is 0.021425364803019153
# * Generation 101 is fin. the minimum value is 0.021425364803019153
# * Generation 102 is fin. the minimum value is 0.021425364803019153
# * Generation 103 is fin. the minimum value is 0.021425364803019153
# * Generation 104 is fin. the minimum value is 0.01721295552785973
# * Generation 105 is fin. the minimum value is 0.012027536880292011
# * Generation 106 is fin. the minimum value is 0.012027536880292011
# * Generation 107 is fin. the minimum value is 0.012027536880292011
# * Generation 108 is fin. the minimum value is 0.011686645133827778
# * Generation 109 is fin. the minimum value is 0.011224187335791225
# * Generation 110 is fin. the minimum value is 0.008239220845950967
# * Generation 111 is fin. the minimum value is 0.008239220845950967
# * Generation 112 is fin. the minimum value is 0.008239220845950967
# * Generation 113 is fin. the minimum value is 0.007568252355459659
# * Generation 114 is fin. the minimum value is 0.007568252355459659
# * Generation 115 is fin. the minimum value is 0.007568252355459659
# * Generation 116 is fin. the minimum value is 0.007568252355459659
# * Generation 117 is fin. the minimum value is 0.005964857103931909
# * Generation 118 is fin. the minimum value is 0.005964857103931909
# * Generation 119 is fin. the minimum value is 0.006646981152758968
# * Generation 120 is fin. the minimum value is 0.005716625095641525
# * Generation 121 is fin. the minimum value is 0.005046396598484382
# * Generation 122 is fin. the minimum value is 0.004434598744906815
# * Generation 123 is fin. the minimum value is 0.004434598744906815
# * Generation 124 is fin. the minimum value is 0.004434598744906815
# * Generation 125 is fin. the minimum value is 0.004434598744906815
# * Generation 126 is fin. the minimum value is 0.004434598744906815
# * Generation 127 is fin. the minimum value is 0.0037950928409578033
# * Generation 128 is fin. the minimum value is 0.0037950928409578033
# * Generation 129 is fin. the minimum value is 0.0037950928409578033
# * Generation 130 is fin. the minimum value is 0.0035077240274716814
# * Generation 131 is fin. the minimum value is 0.0035077240274716814
# * Generation 132 is fin. the minimum value is 0.0034358665126608123
# * Generation 133 is fin. the minimum value is 0.0034358665126608123
# * Generation 134 is fin. the minimum value is 0.002958148618554368
# * Generation 135 is fin. the minimum value is 0.0028076107443992804
# * Generation 136 is fin. the minimum value is 0.0028076107443992804
# * Generation 137 is fin. the minimum value is 0.0025574042417062515
# * Generation 138 is fin. the minimum value is 0.0018922089461304026
# * Generation 139 is fin. the minimum value is 0.0018922089461304026
# * Generation 140 is fin. the minimum value is 0.0018922089461304026
# * Generation 141 is fin. the minimum value is 0.0018922089461304026
# * Generation 142 is fin. the minimum value is 0.001986121726713641
# * Generation 143 is fin. the minimum value is 0.0017047725500183297
# * Generation 144 is fin. the minimum value is 0.0014379265143253939
# * Generation 145 is fin. the minimum value is 0.0014379265143253939
# * Generation 146 is fin. the minimum value is 0.0014379265143253939
# * Generation 147 is fin. the minimum value is 0.0008489894857302005
# * Generation 148 is fin. the minimum value is 0.0008489894857302005
# * Generation 149 is fin. the minimum value is 0.0008489894857302005
# * Generation 150 is fin. the minimum value is 0.0008489894857302005
# * Generation 151 is fin. the minimum value is 0.0008489894857302005
# * Generation 152 is fin. the minimum value is 0.0008489894857302005
# * Generation 153 is fin. the minimum value is 0.0009620328812669499
# * Generation 154 is fin. the minimum value is 0.0009620328812669499
# * Generation 155 is fin. the minimum value is 0.0008858177055000027
# * Generation 156 is fin. the minimum value is 0.0008845930916332456
# * Generation 157 is fin. the minimum value is 0.0007447304960610523
# * Generation 158 is fin. the minimum value is 0.0006624204455594196
# * Generation 159 is fin. the minimum value is 0.0006624204455594196
# * Generation 160 is fin. the minimum value is 0.0006624204455594196
# * Generation 161 is fin. the minimum value is 0.0006624204455594196
# * Generation 162 is fin. the minimum value is 0.0005386996783207643
# * Generation 163 is fin. the minimum value is 0.0006129339878611084
# * Generation 164 is fin. the minimum value is 0.0005232977935651917
# * Generation 165 is fin. the minimum value is 0.0004374198152659048
# * Generation 166 is fin. the minimum value is 0.0004374198152659048
# * Generation 167 is fin. the minimum value is 0.0004374198152659048
# * Generation 168 is fin. the minimum value is 0.0004374198152659048
# * Generation 169 is fin. the minimum value is 0.00038991771266383424
# * Generation 170 is fin. the minimum value is 0.00038991771266383424
# * Generation 171 is fin. the minimum value is 0.00038991771266383424
# * Generation 172 is fin. the minimum value is 0.0003888981546307235
# * Generation 173 is fin. the minimum value is 0.00035988972022682475
# * Generation 174 is fin. the minimum value is 0.0003186583377075003
# * Generation 175 is fin. the minimum value is 0.0003186583377075003
# * Generation 176 is fin. the minimum value is 0.0002804802029001685
# * Generation 177 is fin. the minimum value is 0.0002634909846643829
# * Generation 178 is fin. the minimum value is 0.0002634909846643829
# * Generation 179 is fin. the minimum value is 0.0002634909846643829
# * Generation 180 is fin. the minimum value is 0.0002589335598965903
# * Generation 181 is fin. the minimum value is 0.00019429991396435753
# * Generation 182 is fin. the minimum value is 0.00019429991396435753
# * Generation 183 is fin. the minimum value is 0.00011035029626027537
# * Generation 184 is fin. the minimum value is 0.00020645268667562888
# * Generation 185 is fin. the minimum value is 0.00019558379392581315
# * Generation 186 is fin. the minimum value is 0.00017119454464031847
# * Generation 187 is fin. the minimum value is 0.0001581402939128118
# * Generation 188 is fin. the minimum value is 0.00013857689862417644
# * Generation 189 is fin. the minimum value is 9.090074629414246e-05
# * Generation 190 is fin. the minimum value is 9.090074629414246e-05
# * Generation 191 is fin. the minimum value is 9.090074629414246e-05
# * Generation 192 is fin. the minimum value is 9.090074629414246e-05
# * Generation 193 is fin. the minimum value is 0.0001032433166399116
# * Generation 194 is fin. the minimum value is 7.906842763194533e-05
# * Generation 195 is fin. the minimum value is 7.906842763194533e-05
# * Generation 196 is fin. the minimum value is 7.906842763194533e-05
# * Generation 197 is fin. the minimum value is 7.906842763194533e-05
# * Generation 198 is fin. the minimum value is 7.906842763194533e-05
# * Generation 199 is fin. the minimum value is 6.902677153419745e-05
# * Generation 200 is fin. the minimum value is 6.902677153419745e-05
# * Generation 201 is fin. the minimum value is 6.902677153419745e-05
# * Generation 202 is fin. the minimum value is 6.173729627567681e-05
# * Generation 203 is fin. the minimum value is 5.2249295483974834e-05
# * Generation 204 is fin. the minimum value is 5.2249295483974834e-05
# * Generation 205 is fin. the minimum value is 5.2249295483974834e-05
# * Generation 206 is fin. the minimum value is 4.881018227909095e-05
# * Generation 207 is fin. the minimum value is 3.5239056104696687e-05
# * Generation 208 is fin. the minimum value is 3.5239056104696687e-05
# * Generation 209 is fin. the minimum value is 3.5239056104696687e-05
# * Generation 210 is fin. the minimum value is 3.5239056104696687e-05
# * Generation 211 is fin. the minimum value is 3.5239056104696687e-05
# * Generation 212 is fin. the minimum value is 3.518250013589963e-05
# * Generation 213 is fin. the minimum value is 3.518250013589963e-05
# * Generation 214 is fin. the minimum value is 3.028691978990139e-05
# * Generation 215 is fin. the minimum value is 2.982509868454386e-05
# * Generation 216 is fin. the minimum value is 2.6340177924577546e-05
# * Generation 217 is fin. the minimum value is 2.6340177924577546e-05
# * Generation 218 is fin. the minimum value is 2.6340177924577546e-05
# * Generation 219 is fin. the minimum value is 2.302245606555786e-05
# * Generation 220 is fin. the minimum value is 2.302245606555786e-05
# * Generation 221 is fin. the minimum value is 2.302245606555786e-05
# * Generation 222 is fin. the minimum value is 2.0498933431145616e-05
# * Generation 223 is fin. the minimum value is 2.0498933431145616e-05
# * Generation 224 is fin. the minimum value is 2.0498933431145616e-05
# * Generation 225 is fin. the minimum value is 2.0142960545754818e-05
# * Generation 226 is fin. the minimum value is 2.0142960545754818e-05
# * Generation 227 is fin. the minimum value is 1.6351130357694643e-05
# * Generation 228 is fin. the minimum value is 1.303572247746132e-05
# * Generation 229 is fin. the minimum value is 1.303572247746132e-05
# * Generation 230 is fin. the minimum value is 1.303572247746132e-05
# * Generation 231 is fin. the minimum value is 1.303572247746132e-05
# * Generation 232 is fin. the minimum value is 1.209781831734702e-05
# * Generation 233 is fin. the minimum value is 1.209781831734702e-05
# * Generation 234 is fin. the minimum value is 1.209781831734702e-05
# * Generation 235 is fin. the minimum value is 1.209781831734702e-05
# * Generation 236 is fin. the minimum value is 1.086536323535725e-05
# * Generation 237 is fin. the minimum value is 1.086536323535725e-05
# * Generation 238 is fin. the minimum value is 8.23067520494547e-06
# * Generation 239 is fin. the minimum value is 8.23067520494547e-06
# * Generation 240 is fin. the minimum value is 8.23067520494547e-06
# * Generation 241 is fin. the minimum value is 8.23067520494547e-06
# * Generation 242 is fin. the minimum value is 7.598048317181139e-06
# * Generation 243 is fin. the minimum value is 6.1180437378460795e-06
# * Generation 244 is fin. the minimum value is 6.1180437378460795e-06
# * Generation 245 is fin. the minimum value is 6.1180437378460795e-06
# * Generation 246 is fin. the minimum value is 6.1180437378460795e-06
# * Generation 247 is fin. the minimum value is 6.1180437378460795e-06
# * Generation 248 is fin. the minimum value is 6.1180437378460795e-06
# * Generation 249 is fin. the minimum value is 6.094310883497656e-06
# * Generation 250 is fin. the minimum value is 6.047623063665242e-06
# * Generation 251 is fin. the minimum value is 5.371717014757138e-06
# * Generation 252 is fin. the minimum value is 5.371717014757138e-06
# * Generation 253 is fin. the minimum value is 5.371717014757138e-06
# * Generation 254 is fin. the minimum value is 4.943388682843164e-06
# * Generation 255 is fin. the minimum value is 4.809607168976271e-06
# * Generation 256 is fin. the minimum value is 4.809607168976271e-06
# * Generation 257 is fin. the minimum value is 4.220166434532047e-06
# * Generation 258 is fin. the minimum value is 4.375158341396457e-06
# * Generation 259 is fin. the minimum value is 4.014917079686597e-06
# * Generation 260 is fin. the minimum value is 3.6560724727685567e-06
# * Generation 261 is fin. the minimum value is 3.3488093600375635e-06
# * Generation 262 is fin. the minimum value is 3.303067079851729e-06
# * Generation 263 is fin. the minimum value is 3.279215352591791e-06
# * Generation 264 is fin. the minimum value is 2.427739461463574e-06
# * Generation 265 is fin. the minimum value is 2.427739461463574e-06
# * Generation 266 is fin. the minimum value is 2.427739461463574e-06
# * Generation 267 is fin. the minimum value is 2.34636654905529e-06
# * Generation 268 is fin. the minimum value is 2.34636654905529e-06
# * Generation 269 is fin. the minimum value is 2.34636654905529e-06
# * Generation 270 is fin. the minimum value is 2.1221452999320434e-06
# * Generation 271 is fin. the minimum value is 1.613028483671286e-06
# * Generation 272 is fin. the minimum value is 1.613028483671286e-06
# * Generation 273 is fin. the minimum value is 1.5192559619237045e-06
# * Generation 274 is fin. the minimum value is 1.4922440203513077e-06
# * Generation 275 is fin. the minimum value is 1.4922440203513077e-06
# * Generation 276 is fin. the minimum value is 1.2785176468632642e-06
# * Generation 277 is fin. the minimum value is 1.061857439754732e-06
# * Generation 278 is fin. the minimum value is 1.061857439754732e-06
# * Generation 279 is fin. the minimum value is 1.061857439754732e-06
# * Generation 280 is fin. the minimum value is 1.061857439754732e-06
# * Generation 281 is fin. the minimum value is 1.061857439754732e-06
# * Generation 282 is fin. the minimum value is 1.061857439754732e-06
# * Generation 283 is fin. the minimum value is 1.1472074996632387e-06
# * Generation 284 is fin. the minimum value is 1.0143712154686568e-06
# * Generation 285 is fin. the minimum value is 1.0143712154686568e-06
# * Generation 286 is fin. the minimum value is 1.0020277221300944e-06
# * Generation 287 is fin. the minimum value is 8.720148576557563e-07
# * Generation 288 is fin. the minimum value is 7.48085824842093e-07
# * Generation 289 is fin. the minimum value is 7.48085824842093e-07
# * Generation 290 is fin. the minimum value is 7.266253034821091e-07
# * Generation 291 is fin. the minimum value is 6.142248105689418e-07
# * Generation 292 is fin. the minimum value is 6.142248105689418e-07
# * Generation 293 is fin. the minimum value is 6.142248105689418e-07
# * Generation 294 is fin. the minimum value is 6.142248105689418e-07
# * Generation 295 is fin. the minimum value is 5.785077119568882e-07
# * Generation 296 is fin. the minimum value is 4.0693735403607434e-07
# * Generation 297 is fin. the minimum value is 4.0693735403607434e-07
# * Generation 298 is fin. the minimum value is 4.0693735403607434e-07
# * Generation 299 is fin. the minimum value is 2.742424420887346e-07
# * Generation 300 is fin. the minimum value is 2.742424420887346e-07
# * Generation 301 is fin. the minimum value is 2.742424420887346e-07
# * Generation 302 is fin. the minimum value is 2.742424420887346e-07
# * Generation 303 is fin. the minimum value is 2.742424420887346e-07
# * Generation 304 is fin. the minimum value is 2.742424420887346e-07
# * Generation 305 is fin. the minimum value is 2.3613250910159422e-07
# * Generation 306 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 307 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 308 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 309 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 310 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 311 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 312 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 313 is fin. the minimum value is 1.5342708881149747e-07
# * Generation 314 is fin. the minimum value is 1.5023945909575787e-07
# * Generation 315 is fin. the minimum value is 1.5023945909575787e-07
# * Generation 316 is fin. the minimum value is 1.2248257252878147e-07
# * Generation 317 is fin. the minimum value is 1.3472492454980056e-07
# * Generation 318 is fin. the minimum value is 1.3301945323007658e-07
# * Generation 319 is fin. the minimum value is 9.895154651218263e-08
# * Generation 320 is fin. the minimum value is 1.1676685174322188e-07
# * Generation 321 is fin. the minimum value is 1.0706285502593005e-07
# * Generation 322 is fin. the minimum value is 9.338293782690243e-08
# * Generation 323 is fin. the minimum value is 9.955164603780986e-08
# * Generation 324 is fin. the minimum value is 9.955164603780986e-08
# * Generation 325 is fin. the minimum value is 9.520272747920444e-08
# * Generation 326 is fin. the minimum value is 7.501347543126258e-08
# * Generation 327 is fin. the minimum value is 7.501347543126258e-08
# * Generation 328 is fin. the minimum value is 6.352937687026383e-08
# * Generation 329 is fin. the minimum value is 7.132394541642384e-08
# * Generation 330 is fin. the minimum value is 7.132394541642384e-08
# * Generation 331 is fin. the minimum value is 6.59768097932556e-08
# * Generation 332 is fin. the minimum value is 4.799223818352516e-08
# * Generation 333 is fin. the minimum value is 4.799223818352516e-08
# * Generation 334 is fin. the minimum value is 4.799223818352516e-08
# * Generation 335 is fin. the minimum value is 4.799223818352516e-08
# * Generation 336 is fin. the minimum value is 4.799223818352516e-08
# * Generation 337 is fin. the minimum value is 4.482420079554572e-08
# * Generation 338 is fin. the minimum value is 4.482420079554572e-08
# * Generation 339 is fin. the minimum value is 4.482420079554572e-08
# * Generation 340 is fin. the minimum value is 4.207200854366988e-08
# * Generation 341 is fin. the minimum value is 3.691741801148396e-08
# * Generation 342 is fin. the minimum value is 3.6264201863644985e-08
# * Generation 343 is fin. the minimum value is 2.5423420257908447e-08
# * Generation 344 is fin. the minimum value is 2.5423420257908447e-08
# * Generation 345 is fin. the minimum value is 2.5423420257908447e-08
# * Generation 346 is fin. the minimum value is 2.5423420257908447e-08
# * Generation 347 is fin. the minimum value is 2.5423420257908447e-08
# * Generation 348 is fin. the minimum value is 2.5354533139676505e-08
# * Generation 349 is fin. the minimum value is 2.4681240162749418e-08
# * Generation 350 is fin. the minimum value is 2.401571341792419e-08
# * Generation 351 is fin. the minimum value is 1.870254084934686e-08
# * Generation 352 is fin. the minimum value is 1.870254084934686e-08
# * Generation 353 is fin. the minimum value is 1.870254084934686e-08
# * Generation 354 is fin. the minimum value is 1.870254084934686e-08
# * Generation 355 is fin. the minimum value is 1.6636641397838048e-08
# * Generation 356 is fin. the minimum value is 1.6636641397838048e-08
# * Generation 357 is fin. the minimum value is 1.584060971282497e-08
# * Generation 358 is fin. the minimum value is 1.3544984245328351e-08
# * Generation 359 is fin. the minimum value is 1.2971949292506224e-08
# * Generation 360 is fin. the minimum value is 1.2469290044947456e-08
# * Generation 361 is fin. the minimum value is 1.2469290044947456e-08
# * Generation 362 is fin. the minimum value is 1.1187758275355009e-08
# * Generation 363 is fin. the minimum value is 1.0353801371820737e-08
# * Generation 364 is fin. the minimum value is 1.0353801371820737e-08
# * Generation 365 is fin. the minimum value is 8.583992183730516e-09
# * Generation 366 is fin. the minimum value is 8.583992183730516e-09
# * Generation 367 is fin. the minimum value is 7.852484884551814e-09
# * Generation 368 is fin. the minimum value is 7.852484884551814e-09
# * Generation 369 is fin. the minimum value is 7.852484884551814e-09
# * Generation 370 is fin. the minimum value is 7.852484884551814e-09
# * Generation 371 is fin. the minimum value is 5.489614096632067e-09
# * Generation 372 is fin. the minimum value is 5.155204263473934e-09
# * Generation 373 is fin. the minimum value is 5.155204263473934e-09
# * Generation 374 is fin. the minimum value is 4.5378172330856614e-09
# * Generation 375 is fin. the minimum value is 4.5378172330856614e-09
# * Generation 376 is fin. the minimum value is 4.5378172330856614e-09
# * Generation 377 is fin. the minimum value is 4.5378172330856614e-09
# * Generation 378 is fin. the minimum value is 4.704961753532189e-09
# * Generation 379 is fin. the minimum value is 4.644313378321385e-09
# * Generation 380 is fin. the minimum value is 3.391996017398924e-09
# * Generation 381 is fin. the minimum value is 3.391996017398924e-09
# * Generation 382 is fin. the minimum value is 3.391996017398924e-09
# * Generation 383 is fin. the minimum value is 3.093866496328701e-09
# * Generation 384 is fin. the minimum value is 3.093866496328701e-09
# * Generation 385 is fin. the minimum value is 2.5043718210326915e-09
# * Generation 386 is fin. the minimum value is 2.329720416582859e-09
# * Generation 387 is fin. the minimum value is 2.1092994018090394e-09
# * Generation 388 is fin. the minimum value is 2.1092994018090394e-09
# * Generation 389 is fin. the minimum value is 2.05903560868137e-09
# * Generation 390 is fin. the minimum value is 1.9776926762915537e-09
# * Generation 391 is fin. the minimum value is 1.6468391095258994e-09
# * Generation 392 is fin. the minimum value is 1.6468391095258994e-09
# * Generation 393 is fin. the minimum value is 1.4109744483903341e-09
# * Generation 394 is fin. the minimum value is 1.4109744483903341e-09
# * Generation 395 is fin. the minimum value is 1.377301828142663e-09
# * Generation 396 is fin. the minimum value is 1.377301828142663e-09
# * Generation 397 is fin. the minimum value is 1.2343228661393368e-09
# * Generation 398 is fin. the minimum value is 1.1203198369003076e-09
# * Generation 399 is fin. the minimum value is 1.160806561983918e-09
# * Generation 400 is fin. the minimum value is 9.189129457354284e-10
# * Generation 401 is fin. the minimum value is 9.189129457354284e-10
# * Generation 402 is fin. the minimum value is 8.549640995170193e-10
# * Generation 403 is fin. the minimum value is 8.549640995170193e-10
# * Generation 404 is fin. the minimum value is 8.549640995170193e-10
# * Generation 405 is fin. the minimum value is 7.288605274879956e-10
# * Generation 406 is fin. the minimum value is 7.288605274879956e-10
# * Generation 407 is fin. the minimum value is 5.765024013726361e-10
# * Generation 408 is fin. the minimum value is 5.765024013726361e-10
# * Generation 409 is fin. the minimum value is 4.994689106752048e-10
# * Generation 410 is fin. the minimum value is 4.994689106752048e-10
# * Generation 411 is fin. the minimum value is 4.2091485852324695e-10
# * Generation 412 is fin. the minimum value is 4.985594159734319e-10
# * Generation 413 is fin. the minimum value is 4.831655076031893e-10
# * Generation 414 is fin. the minimum value is 4.211422321986902e-10
# * Generation 415 is fin. the minimum value is 4.211422321986902e-10
# * Generation 416 is fin. the minimum value is 3.9405989582519396e-10
# * Generation 417 is fin. the minimum value is 3.9405989582519396e-10
# * Generation 418 is fin. the minimum value is 3.630482581229444e-10
# * Generation 419 is fin. the minimum value is 3.427160777391691e-10
# * Generation 420 is fin. the minimum value is 3.050075747523806e-10
# * Generation 421 is fin. the minimum value is 3.050075747523806e-10
# * Generation 422 is fin. the minimum value is 3.050075747523806e-10
# * Generation 423 is fin. the minimum value is 3.050075747523806e-10
# * Generation 424 is fin. the minimum value is 3.0186342314664216e-10
# * Generation 425 is fin. the minimum value is 3.0186342314664216e-10
# * Generation 426 is fin. the minimum value is 2.7840130201184365e-10
# * Generation 427 is fin. the minimum value is 2.7142021963300067e-10
# * Generation 428 is fin. the minimum value is 2.4647661689414235e-10
# * Generation 429 is fin. the minimum value is 2.4647661689414235e-10
# * Generation 430 is fin. the minimum value is 1.6275336633952975e-10
# * Generation 431 is fin. the minimum value is 1.6275336633952975e-10
# * Generation 432 is fin. the minimum value is 1.6275336633952975e-10
# * Generation 433 is fin. the minimum value is 2.0340351625236508e-10
# * Generation 434 is fin. the minimum value is 2.0340351625236508e-10
# * Generation 435 is fin. the minimum value is 1.7818635456023912e-10
# * Generation 436 is fin. the minimum value is 1.5774759276609984e-10
# * Generation 437 is fin. the minimum value is 1.4507151036013965e-10
# * Generation 438 is fin. the minimum value is 1.4507151036013965e-10
# * Generation 439 is fin. the minimum value is 1.2997958265259513e-10
# * Generation 440 is fin. the minimum value is 1.2997958265259513e-10
# * Generation 441 is fin. the minimum value is 1.1328893378959037e-10
# * Generation 442 is fin. the minimum value is 1.1328893378959037e-10
# * Generation 443 is fin. the minimum value is 1.1463185956017696e-10
# * Generation 444 is fin. the minimum value is 9.907097364703077e-11
# * Generation 445 is fin. the minimum value is 9.907097364703077e-11
# * Generation 446 is fin. the minimum value is 9.7909236274063e-11
# * Generation 447 is fin. the minimum value is 9.7909236274063e-11
# * Generation 448 is fin. the minimum value is 8.922285132939578e-11
# * Generation 449 is fin. the minimum value is 8.355272029803018e-11
# * Generation 450 is fin. the minimum value is 6.924949502717936e-11
# * Generation 451 is fin. the minimum value is 6.924949502717936e-11
# * Generation 452 is fin. the minimum value is 6.924949502717936e-11
# * Generation 453 is fin. the minimum value is 6.924949502717936e-11
# * Generation 454 is fin. the minimum value is 6.437517185986508e-11
# * Generation 455 is fin. the minimum value is 5.715605766454246e-11
# * Generation 456 is fin. the minimum value is 5.927347501710756e-11
# * Generation 457 is fin. the minimum value is 5.494626975632855e-11
# * Generation 458 is fin. the minimum value is 4.5989878572072485e-11
# * Generation 459 is fin. the minimum value is 4.2103209807464737e-11
# * Generation 460 is fin. the minimum value is 4.2103209807464737e-11
# * Generation 461 is fin. the minimum value is 4.2103209807464737e-11
# * Generation 462 is fin. the minimum value is 3.8401282154154615e-11
# * Generation 463 is fin. the minimum value is 3.83160170258634e-11
# * Generation 464 is fin. the minimum value is 3.83160170258634e-11
# * Generation 465 is fin. the minimum value is 3.1953106827131705e-11
# * Generation 466 is fin. the minimum value is 2.928857156803133e-11
# * Generation 467 is fin. the minimum value is 2.5124791136477143e-11
# * Generation 468 is fin. the minimum value is 2.5124791136477143e-11
# * Generation 469 is fin. the minimum value is 2.5210056264768355e-11
# * Generation 470 is fin. the minimum value is 2.3309354446610087e-11
# * Generation 471 is fin. the minimum value is 1.680788841440517e-11
# * Generation 472 is fin. the minimum value is 1.680788841440517e-11
# * Generation 473 is fin. the minimum value is 1.8253842881676974e-11
# * Generation 474 is fin. the minimum value is 1.8253842881676974e-11
# * Generation 475 is fin. the minimum value is 1.4793499758525286e-11
# * Generation 476 is fin. the minimum value is 1.568167817822541e-11
# * Generation 477 is fin. the minimum value is 1.568167817822541e-11
# * Generation 478 is fin. the minimum value is 1.262634441445698e-11
# * Generation 479 is fin. the minimum value is 1.262634441445698e-11
# * Generation 480 is fin. the minimum value is 1.262634441445698e-11
# * Generation 481 is fin. the minimum value is 1.084643486137793e-11
# * Generation 482 is fin. the minimum value is 1.0928147275990341e-11
# * Generation 483 is fin. the minimum value is 8.828493491819245e-12
# * Generation 484 is fin. the minimum value is 8.828493491819245e-12
# * Generation 485 is fin. the minimum value is 8.828493491819245e-12
# * Generation 486 is fin. the minimum value is 7.613465413669473e-12
# * Generation 487 is fin. the minimum value is 7.613465413669473e-12
# * Generation 488 is fin. the minimum value is 7.613465413669473e-12
# * Generation 489 is fin. the minimum value is 6.87805368215777e-12
# * Generation 490 is fin. the minimum value is 5.8548721426632255e-12
# * Generation 491 is fin. the minimum value is 5.8548721426632255e-12
# * Generation 492 is fin. the minimum value is 4.206412995699793e-12
# * Generation 493 is fin. the minimum value is 3.986144747614162e-12
# * Generation 494 is fin. the minimum value is 4.007461029686965e-12
# * Generation 495 is fin. the minimum value is 4.007461029686965e-12
# * Generation 496 is fin. the minimum value is 4.007461029686965e-12
# * Generation 497 is fin. the minimum value is 4.007461029686965e-12
# * Generation 498 is fin. the minimum value is 3.744560217455728e-12
# * Generation 499 is fin. the minimum value is 3.5349501104064984e-12
# * Generation 500 is fin. the minimum value is 2.8776980798284058e-12
# * Generation 501 is fin. the minimum value is 2.8776980798284058e-12
# * Generation 502 is fin. the minimum value is 2.8776980798284058e-12
# * Generation 503 is fin. the minimum value is 2.8776980798284058e-12
# * Generation 504 is fin. the minimum value is 2.19912976717751e-12
# * Generation 505 is fin. the minimum value is 2.19912976717751e-12
# * Generation 506 is fin. the minimum value is 1.957545237019076e-12
# * Generation 507 is fin. the minimum value is 1.4992451724538114e-12
# * Generation 508 is fin. the minimum value is 1.4992451724538114e-12
# * Generation 509 is fin. the minimum value is 1.4992451724538114e-12
# * Generation 510 is fin. the minimum value is 1.4992451724538114e-12
# * Generation 511 is fin. the minimum value is 1.4992451724538114e-12
# * Generation 512 is fin. the minimum value is 1.3322676295501878e-12
# * Generation 513 is fin. the minimum value is 1.3322676295501878e-12
# * Generation 514 is fin. the minimum value is 1.4992451724538114e-12
# * Generation 515 is fin. the minimum value is 1.4175327578413999e-12
# * Generation 516 is fin. the minimum value is 1.4175327578413999e-12
# * Generation 517 is fin. the minimum value is 1.3464784842653899e-12
# * Generation 518 is fin. the minimum value is 1.2647660696529783e-12
# * Generation 519 is fin. the minimum value is 8.846257060213247e-13
# * Generation 520 is fin. the minimum value is 8.846257060213247e-13
# * Generation 521 is fin. the minimum value is 8.846257060213247e-13
# * Generation 522 is fin. the minimum value is 8.206768598029157e-13
# * Generation 523 is fin. the minimum value is 8.846257060213247e-13
# * Generation 524 is fin. the minimum value is 7.212008767965017e-13
# * Generation 525 is fin. the minimum value is 8.846257060213247e-13
# * Generation 526 is fin. the minimum value is 8.490985692333197e-13
# * Generation 527 is fin. the minimum value is 7.993605777301127e-13
# * Generation 528 is fin. the minimum value is 6.217248937900877e-13
# * Generation 529 is fin. the minimum value is 5.613287612504791e-13
# * Generation 530 is fin. the minimum value is 4.511946372076636e-13
# * Generation 531 is fin. the minimum value is 4.511946372076636e-13
# * Generation 532 is fin. the minimum value is 4.511946372076636e-13
# * Generation 533 is fin. the minimum value is 4.511946372076636e-13
# * Generation 534 is fin. the minimum value is 3.979039320256561e-13
# * Generation 535 is fin. the minimum value is 3.979039320256561e-13
# * Generation 536 is fin. the minimum value is 3.979039320256561e-13
# * Generation 537 is fin. the minimum value is 3.872457909892546e-13
# * Generation 538 is fin. the minimum value is 3.872457909892546e-13
# * Generation 539 is fin. the minimum value is 3.872457909892546e-13
# * Generation 540 is fin. the minimum value is 3.765876499528531e-13
# * Generation 541 is fin. the minimum value is 3.765876499528531e-13
# * Generation 542 is fin. the minimum value is 3.126388037344441e-13
# * Generation 543 is fin. the minimum value is 3.126388037344441e-13
# * Generation 544 is fin. the minimum value is 3.055333763768431e-13
# * Generation 545 is fin. the minimum value is 2.0961010704922955e-13
# * Generation 546 is fin. the minimum value is 2.6290081223123707e-13
# * Generation 547 is fin. the minimum value is 2.6290081223123707e-13
# * Generation 548 is fin. the minimum value is 2.0961010704922955e-13
# * Generation 549 is fin. the minimum value is 2.0961010704922955e-13
# * Generation 550 is fin. the minimum value is 1.9184653865522705e-13
# * Generation 551 is fin. the minimum value is 1.9184653865522705e-13
# * Generation 552 is fin. the minimum value is 1.9184653865522705e-13
# * Generation 553 is fin. the minimum value is 1.9184653865522705e-13
# * Generation 554 is fin. the minimum value is 1.8829382497642655e-13
# * Generation 555 is fin. the minimum value is 1.8829382497642655e-13
# * Generation 556 is fin. the minimum value is 1.8118839761882555e-13
# * Generation 557 is fin. the minimum value is 1.4566126083082054e-13
# * Generation 558 is fin. the minimum value is 1.4566126083082054e-13
# * Generation 559 is fin. the minimum value is 1.7053025658242404e-13
# * Generation 560 is fin. the minimum value is 1.4210854715202004e-13
# * Generation 561 is fin. the minimum value is 1.1013412404281553e-13
# * Generation 562 is fin. the minimum value is 1.1013412404281553e-13
# * Generation 563 is fin. the minimum value is 1.1013412404281553e-13
# * Generation 564 is fin. the minimum value is 1.1368683772161603e-13
# * Generation 565 is fin. the minimum value is 9.947598300641403e-14
# * Generation 566 is fin. the minimum value is 9.947598300641403e-14
# * Generation 567 is fin. the minimum value is 8.526512829121202e-14
# * Generation 568 is fin. the minimum value is 7.460698725481052e-14
# * Generation 569 is fin. the minimum value is 7.460698725481052e-14
# * Generation 570 is fin. the minimum value is 7.460698725481052e-14
# * Generation 571 is fin. the minimum value is 6.750155989720952e-14
# * Generation 572 is fin. the minimum value is 6.394884621840902e-14
# * Generation 573 is fin. the minimum value is 4.263256414560601e-14
# * Generation 574 is fin. the minimum value is 4.263256414560601e-14
# * Generation 575 is fin. the minimum value is 4.263256414560601e-14
# * Generation 576 is fin. the minimum value is 3.907985046680551e-14
# * Generation 577 is fin. the minimum value is 3.907985046680551e-14
# * Generation 578 is fin. the minimum value is 3.907985046680551e-14
# * Generation 579 is fin. the minimum value is 3.907985046680551e-14
# * Generation 580 is fin. the minimum value is 3.907985046680551e-14
# * Generation 581 is fin. the minimum value is 3.907985046680551e-14
# * Generation 582 is fin. the minimum value is 2.842170943040401e-14
# * Generation 583 is fin. the minimum value is 2.842170943040401e-14
# * Generation 584 is fin. the minimum value is 2.842170943040401e-14
# * Generation 585 is fin. the minimum value is 2.842170943040401e-14
# * Generation 586 is fin. the minimum value is 2.842170943040401e-14
# * Generation 587 is fin. the minimum value is 2.842170943040401e-14
# * Generation 588 is fin. the minimum value is 2.842170943040401e-14
# * Generation 589 is fin. the minimum value is 2.842170943040401e-14
# * Generation 590 is fin. the minimum value is 2.842170943040401e-14
# * Generation 591 is fin. the minimum value is 2.4868995751603507e-14
# * Generation 592 is fin. the minimum value is 2.4868995751603507e-14
# * Generation 593 is fin. the minimum value is 1.7763568394002505e-14
# * Generation 594 is fin. the minimum value is 1.7763568394002505e-14
# * Generation 595 is fin. the minimum value is 1.7763568394002505e-14
# * Generation 596 is fin. the minimum value is 1.7763568394002505e-14
# * Generation 597 is fin. the minimum value is 1.4210854715202004e-14
# * Generation 598 is fin. the minimum value is 1.4210854715202004e-14
# * Generation 599 is fin. the minimum value is 1.4210854715202004e-14
# * Generation 600 is fin. the minimum value is 1.4210854715202004e-14
# * Generation 601 is fin. the minimum value is 1.0658141036401503e-14
# * Generation 602 is fin. the minimum value is 1.0658141036401503e-14
# * Generation 603 is fin. the minimum value is 7.105427357601002e-15
# * Generation 604 is fin. the minimum value is 7.105427357601002e-15
# * Generation 605 is fin. the minimum value is 7.105427357601002e-15
# * Generation 606 is fin. the minimum value is 7.105427357601002e-15
# * Generation 607 is fin. the minimum value is 7.105427357601002e-15
# * Generation 608 is fin. the minimum value is 7.105427357601002e-15
# * Generation 609 is fin. the minimum value is 7.105427357601002e-15
# * Generation 610 is fin. the minimum value is 7.105427357601002e-15
# * Generation 611 is fin. the minimum value is 7.105427357601002e-15
# * Generation 612 is fin. the minimum value is 7.105427357601002e-15
# * Generation 613 is fin. the minimum value is 7.105427357601002e-15
# * Generation 614 is fin. the minimum value is 3.552713678800501e-15
# * Generation 615 is fin. the minimum value is 3.552713678800501e-15
# * Generation 616 is fin. the minimum value is 3.552713678800501e-15
# * Generation 617 is fin. the minimum value is 3.552713678800501e-15
# * Generation 618 is fin. the minimum value is 3.552713678800501e-15
# * Generation 619 is fin. the minimum value is 3.552713678800501e-15
# * Generation 620 is fin. the minimum value is 3.552713678800501e-15
# * Generation 621 is fin. the minimum value is 3.552713678800501e-15
# * Generation 622 is fin. the minimum value is 3.552713678800501e-15
# * Generation 623 is fin. the minimum value is 3.552713678800501e-15
# * Generation 624 is fin. the minimum value is 3.552713678800501e-15
# * Generation 625 is fin. the minimum value is 3.552713678800501e-15
# * Generation 626 is fin. the minimum value is 3.552713678800501e-15
# * Generation 627 is fin. the minimum value is 3.552713678800501e-15
# * Generation 628 is fin. the minimum value is 3.552713678800501e-15
# * Generation 629 is fin. the minimum value is 3.552713678800501e-15
# * Generation 630 is fin. the minimum value is 3.552713678800501e-15
# * Generation 631 is fin. the minimum value is 3.552713678800501e-15
# * Generation 632 is fin. the minimum value is 3.552713678800501e-15
# * Generation 633 is fin. the minimum value is 3.552713678800501e-15
# * Generation 634 is fin. the minimum value is 3.552713678800501e-15
# * Generation 635 is fin. the minimum value is 3.552713678800501e-15
# * Generation 636 is fin. the minimum value is 3.552713678800501e-15
# * Generation 637 is fin. the minimum value is 3.552713678800501e-15
# * Generation 638 is fin. the minimum value is 3.552713678800501e-15
# * Generation 639 is fin. the minimum value is 3.552713678800501e-15
# * Generation 640 is fin. the minimum value is 3.552713678800501e-15
# * Generation 641 is fin. the minimum value is 3.552713678800501e-15
# * Generation 642 is fin. the minimum value is 3.552713678800501e-15
# * Generation 643 is fin. the minimum value is 3.552713678800501e-15
# * Generation 644 is fin. the minimum value is 3.552713678800501e-15
# * Generation 645 is fin. the minimum value is 3.552713678800501e-15
# * Generation 646 is fin. the minimum value is 3.552713678800501e-15
# * Generation 647 is fin. the minimum value is 3.552713678800501e-15
# * Generation 648 is fin. the minimum value is 3.552713678800501e-15
# * Generation 649 is fin. the minimum value is 3.552713678800501e-15
# * Generation 650 is fin. the minimum value is 3.552713678800501e-15
# * Generation 651 is fin. the minimum value is 3.552713678800501e-15
# * Generation 652 is fin. the minimum value is 3.552713678800501e-15
# * Generation 653 is fin. the minimum value is 3.552713678800501e-15
# * Generation 654 is fin. the minimum value is 3.552713678800501e-15
# * Generation 655 is fin. the minimum value is 3.552713678800501e-15
# * Generation 656 is fin. the minimum value is 3.552713678800501e-15
# * Generation 657 is fin. the minimum value is 3.552713678800501e-15
# * Generation 658 is fin. the minimum value is 3.552713678800501e-15
# * Generation 659 is fin. the minimum value is 3.552713678800501e-15
# * Generation 660 is fin. the minimum value is 3.552713678800501e-15
# * Generation 661 is fin. the minimum value is 3.552713678800501e-15
# * Generation 662 is fin. the minimum value is 3.552713678800501e-15
# * Generation 663 is fin. the minimum value is 3.552713678800501e-15
# * Generation 664 is fin. the minimum value is 3.552713678800501e-15
# * Generation 665 is fin. the minimum value is 3.552713678800501e-15
# * Generation 666 is fin. the minimum value is 3.552713678800501e-15
# * Generation 667 is fin. the minimum value is 3.552713678800501e-15
# * Generation 668 is fin. the minimum value is 3.552713678800501e-15
# * Generation 669 is fin. the minimum value is 3.552713678800501e-15
# * Generation 670 is fin. the minimum value is 3.552713678800501e-15
# * Generation 671 is fin. the minimum value is 3.552713678800501e-15
# * Generation 672 is fin. the minimum value is 3.552713678800501e-15
# * Generation 673 is fin. the minimum value is 3.552713678800501e-15
# * Generation 674 is fin. the minimum value is 3.552713678800501e-15
# * Generation 675 is fin. the minimum value is 3.552713678800501e-15
# * Generation 676 is fin. the minimum value is 3.552713678800501e-15
# * Generation 677 is fin. the minimum value is 3.552713678800501e-15
# * Generation 678 is fin. the minimum value is 3.552713678800501e-15
# * Generation 679 is fin. the minimum value is 3.552713678800501e-15
# * Generation 680 is fin. the minimum value is 3.552713678800501e-15
# * Generation 681 is fin. the minimum value is 3.552713678800501e-15
# * Generation 682 is fin. the minimum value is 3.552713678800501e-15
# * Generation 683 is fin. the minimum value is 3.552713678800501e-15
# * Generation 684 is fin. the minimum value is 3.552713678800501e-15
# * Generation 685 is fin. the minimum value is 3.552713678800501e-15
# * Generation 686 is fin. the minimum value is 3.552713678800501e-15
# * Generation 687 is fin. the minimum value is 3.552713678800501e-15
# * Generation 688 is fin. the minimum value is 3.552713678800501e-15
# * Generation 689 is fin. the minimum value is 3.552713678800501e-15
# * Generation 690 is fin. the minimum value is 3.552713678800501e-15
# * Generation 691 is fin. the minimum value is 3.552713678800501e-15
# * Generation 692 is fin. the minimum value is 3.552713678800501e-15
# * Generation 693 is fin. the minimum value is 3.552713678800501e-15
# * Generation 694 is fin. the minimum value is 3.552713678800501e-15
# * Generation 695 is fin. the minimum value is 3.552713678800501e-15
# * Generation 696 is fin. the minimum value is 3.552713678800501e-15
# * Generation 697 is fin. the minimum value is 3.552713678800501e-15
# * Generation 698 is fin. the minimum value is 3.552713678800501e-15
# * Generation 699 is fin. the minimum value is 3.552713678800501e-15
# * Generation 700 is fin. the minimum value is 3.552713678800501e-15
# * Generation 701 is fin. the minimum value is 3.552713678800501e-15
# * Generation 702 is fin. the minimum value is 3.552713678800501e-15
# * Generation 703 is fin. the minimum value is 3.552713678800501e-15
# * Generation 704 is fin. the minimum value is 3.552713678800501e-15
# * Generation 705 is fin. the minimum value is 3.552713678800501e-15
# * Generation 706 is fin. the minimum value is 3.552713678800501e-15
# * Generation 707 is fin. the minimum value is 3.552713678800501e-15
# * Generation 708 is fin. the minimum value is 3.552713678800501e-15
# ...
# * Generation 716 is fin. the minimum value is 3.552713678800501e-15
# * Generation 717 is fin. the minimum value is 3.552713678800501e-15
# * Generation 718 is fin. the minimum value is 3.552713678800501e-15
# * Generation 719 is fin. the minimum value is 3.552713678800501e-15
# * Generation 720 is fin. the minimum value is 3.552713678800501e-15
# * Generation 721 is fin. the minimum value is 3.552713678800501e-15
# * Generation 722 is fin. the minimum value is 3.552713678800501e-15
# * Generation 723 is fin. the minimum value is 3.552713678800501e-15
# * Generation 724 is fin. the minimum value is 3.552713678800501e-15
# * Generation 725 is fin. the minimum value is 3.552713678800501e-15
# * Generation 726 is fin. the minimum value is 3.552713678800501e-15
# * Generation 727 is fin. the minimum value is 3.552713678800501e-15
# * Generation 728 is fin. the minimum value is 3.552713678800501e-15
# * Generation 729 is fin. the minimum value is 3.552713678800501e-15
# * Generation 730 is fin. the minimum value is 3.552713678800501e-15
# * Generation 731 is fin. the minimum value is 3.552713678800501e-15
# * Generation 732 is fin. the minimum value is 3.552713678800501e-15
# * Generation 733 is fin. the minimum value is 3.552713678800501e-15
# * Generation 734 is fin. the minimum value is 3.552713678800501e-15
# * Generation 735 is fin. the minimum value is 3.552713678800501e-15
# * Generation 736 is fin. the minimum value is 3.552713678800501e-15
# * Generation 737 is fin. the minimum value is 3.552713678800501e-15
# * Generation 738 is fin. the minimum value is 3.552713678800501e-15
# * Generation 739 is fin. the minimum value is 3.552713678800501e-15
# * Generation 740 is fin. the minimum value is 3.552713678800501e-15
# * Generation 741 is fin. the minimum value is 3.552713678800501e-15
# * Generation 742 is fin. the minimum value is 3.552713678800501e-15
# * Generation 743 is fin. the minimum value is 3.552713678800501e-15
# * Generation 744 is fin. the minimum value is 3.552713678800501e-15
# * Generation 745 is fin. the minimum value is 3.552713678800501e-15
# * Generation 746 is fin. the minimum value is 3.552713678800501e-15
# * Generation 747 is fin. the minimum value is 3.552713678800501e-15
# * Generation 748 is fin. the minimum value is 3.552713678800501e-15
# * Generation 749 is fin. the minimum value is 3.552713678800501e-15
# * Generation 750 is fin. the minimum value is 3.552713678800501e-15
# * Generation 751 is fin. the minimum value is 3.552713678800501e-15
# * Generation 752 is fin. the minimum value is 3.552713678800501e-15
# * Generation 753 is fin. the minimum value is 3.552713678800501e-15
# * Generation 754 is fin. the minimum value is 3.552713678800501e-15
# * Generation 755 is fin. the minimum value is 3.552713678800501e-15
# * Generation 756 is fin. the minimum value is 3.552713678800501e-15
# * Generation 757 is fin. the minimum value is 3.552713678800501e-15
# * Generation 758 is fin. the minimum value is 3.552713678800501e-15
# * Generation 759 is fin. the minimum value is 3.552713678800501e-15
# * Generation 760 is fin. the minimum value is 3.552713678800501e-15
# * Generation 761 is fin. the minimum value is 3.552713678800501e-15
# * Generation 762 is fin. the minimum value is 3.552713678800501e-15
# * Generation 763 is fin. the minimum value is 3.552713678800501e-15
# * Generation 764 is fin. the minimum value is 3.552713678800501e-15
# * Generation 765 is fin. the minimum value is 3.552713678800501e-15
# * Generation 766 is fin. the minimum value is 3.552713678800501e-15
# * Generation 767 is fin. the minimum value is 3.552713678800501e-15
# * Generation 768 is fin. the minimum value is 3.552713678800501e-15
# * Generation 769 is fin. the minimum value is 3.552713678800501e-15
# * Generation 770 is fin. the minimum value is 3.552713678800501e-15
# * Generation 771 is fin. the minimum value is 3.552713678800501e-15
# * Generation 772 is fin. the minimum value is 3.552713678800501e-15
# * Generation 773 is fin. the minimum value is 3.552713678800501e-15
# * Generation 774 is fin. the minimum value is 3.552713678800501e-15
# * Generation 775 is fin. the minimum value is 3.552713678800501e-15
# * Generation 776 is fin. the minimum value is 3.552713678800501e-15
# * Generation 777 is fin. the minimum value is 3.552713678800501e-15
# * Generation 778 is fin. the minimum value is 0.0
# * Generation 779 is fin. the minimum value is 0.0
# * Generation 780 is fin. the minimum value is 3.552713678800501e-15
# * Generation 781 is fin. the minimum value is 3.552713678800501e-15
# * Generation 782 is fin. the minimum value is 3.552713678800501e-15
# * Generation 783 is fin. the minimum value is 3.552713678800501e-15
# * Generation 784 is fin. the minimum value is 3.552713678800501e-15
# * Generation 785 is fin. the minimum value is 3.552713678800501e-15
# * Generation 786 is fin. the minimum value is 3.552713678800501e-15
# * Generation 787 is fin. the minimum value is 3.552713678800501e-15
# * Generation 788 is fin. the minimum value is 3.552713678800501e-15
# * Generation 789 is fin. the minimum value is 3.552713678800501e-15
# * Generation 790 is fin. the minimum value is 3.552713678800501e-15
# * Generation 791 is fin. the minimum value is 3.552713678800501e-15
# * Generation 792 is fin. the minimum value is 3.552713678800501e-15
# * Generation 793 is fin. the minimum value is 3.552713678800501e-15
# * Generation 794 is fin. the minimum value is 3.552713678800501e-15
# * Generation 795 is fin. the minimum value is 3.552713678800501e-15
# * Generation 796 is fin. the minimum value is 3.552713678800501e-15
# * Generation 797 is fin. the minimum value is 3.552713678800501e-15
# * Generation 798 is fin. the minimum value is 3.552713678800501e-15
# * Generation 799 is fin. the minimum value is 3.552713678800501e-15
# * Generation 800 is fin. the minimum value is 3.552713678800501e-15
# * Generation 801 is fin. the minimum value is 0.0
# * Generation 802 is fin. the minimum value is 0.0
# * Generation 803 is fin. the minimum value is 0.0
# * Generation 804 is fin. the minimum value is 0.0
# * Generation 805 is fin. the minimum value is 0.0
# * Generation 806 is fin. the minimum value is 3.552713678800501e-15
# * Generation 807 is fin. the minimum value is 3.552713678800501e-15
# * Generation 808 is fin. the minimum value is 3.552713678800501e-15
# * Generation 809 is fin. the minimum value is 3.552713678800501e-15
# * Generation 810 is fin. the minimum value is 3.552713678800501e-15
# * Generation 811 is fin. the minimum value is 3.552713678800501e-15
# * Generation 812 is fin. the minimum value is 3.552713678800501e-15
# * Generation 813 is fin. the minimum value is 3.552713678800501e-15
# * Generation 814 is fin. the minimum value is 3.552713678800501e-15
# * Generation 815 is fin. the minimum value is 0.0
# * Generation 816 is fin. the minimum value is 0.0
# * Generation 817 is fin. the minimum value is 0.0
# * Generation 818 is fin. the minimum value is 0.0
# * Generation 819 is fin. the minimum value is 3.552713678800501e-15
# * Generation 820 is fin. the minimum value is 3.552713678800501e-15
# * Generation 821 is fin. the minimum value is 0.0
# * Generation 822 is fin. the minimum value is 0.0
# * Generation 823 is fin. the minimum value is 0.0
# * Generation 824 is fin. the minimum value is 0.0
# * Generation 825 is fin. the minimum value is 0.0
# * Generation 826 is fin. the minimum value is 0.0
# * Generation 827 is fin. the minimum value is 0.0
# * Generation 828 is fin. the minimum value is 0.0
# * Generation 829 is fin. the minimum value is 0.0
# * Generation 830 is fin. the minimum value is 0.0
# * Generation 831 is fin. the minimum value is 0.0
# * Generation 832 is fin. the minimum value is 0.0
# * Generation 833 is fin. the minimum value is 0.0
# * Generation 834 is fin. the minimum value is 0.0
# * Generation 835 is fin. the minimum value is 0.0
# * Generation 836 is fin. the minimum value is 0.0
# * Generation 837 is fin. the minimum value is 0.0
# * Generation 838 is fin. the minimum value is 0.0
# * Generation 839 is fin. the minimum value is 0.0
# * Generation 840 is fin. the minimum value is 0.0
# * Generation 841 is fin. the minimum value is 0.0
# * Generation 842 is fin. the minimum value is 0.0
# * Generation 843 is fin. the minimum value is 0.0
# * Generation 844 is fin. the minimum value is 0.0
# * Generation 845 is fin. the minimum value is 0.0
# * Generation 846 is fin. the minimum value is 0.0
# * Generation 847 is fin. the minimum value is 0.0
# * Generation 848 is fin. the minimum value is 0.0
# * Generation 849 is fin. the minimum value is 0.0
# * Generation 850 is fin. the minimum value is 0.0
# * Generation 851 is fin. the minimum value is 0.0
# * Generation 852 is fin. the minimum value is 0.0
# * Generation 853 is fin. the minimum value is 0.0
# * Generation 854 is fin. the minimum value is 0.0
# * Generation 855 is fin. the minimum value is 0.0
# * Generation 856 is fin. the minimum value is 0.0
# * Generation 857 is fin. the minimum value is 0.0
# * Generation 858 is fin. the minimum value is 0.0
# * Generation 859 is fin. the minimum value is 0.0
# * Generation 860 is fin. the minimum value is 0.0
# * Generation 861 is fin. the minimum value is 0.0
# * Generation 862 is fin. the minimum value is 0.0
# * Generation 863 is fin. the minimum value is 0.0
# * Generation 864 is fin. the minimum value is 0.0
# * Generation 865 is fin. the minimum value is 0.0
# * Generation 866 is fin. the minimum value is 0.0
# * Generation 867 is fin. the minimum value is 0.0
# * Generation 868 is fin. the minimum value is 0.0
# * Generation 869 is fin. the minimum value is 0.0
# * Generation 870 is fin. the minimum value is 0.0
# * Generation 871 is fin. the minimum value is 0.0
# * Generation 872 is fin. the minimum value is 0.0
# * Generation 873 is fin. the minimum value is 0.0
# * Generation 874 is fin. the minimum value is 0.0
# * Generation 875 is fin. the minimum value is 0.0
# * Generation 876 is fin. the minimum value is 0.0
# * Generation 877 is fin. the minimum value is 0.0
# * Generation 878 is fin. the minimum value is 0.0
# * Generation 879 is fin. the minimum value is 0.0
# * Generation 880 is fin. the minimum value is 0.0
# * Generation 881 is fin. the minimum value is 0.0
# * Generation 882 is fin. the minimum value is 0.0
# * Generation 883 is fin. the minimum value is 0.0
# * Generation 884 is fin. the minimum value is 0.0
# * Generation 885 is fin. the minimum value is 0.0
# * Generation 886 is fin. the minimum value is 0.0
# * Generation 887 is fin. the minimum value is 0.0
# * Generation 888 is fin. the minimum value is 0.0
# * Generation 889 is fin. the minimum value is 0.0
# * Generation 890 is fin. the minimum value is 0.0
# * Generation 891 is fin. the minimum value is 0.0
# * Generation 892 is fin. the minimum value is 0.0
# * Generation 893 is fin. the minimum value is 0.0
# * Generation 894 is fin. the minimum value is 0.0
# * Generation 895 is fin. the minimum value is 0.0
# * Generation 896 is fin. the minimum value is 0.0
# * Generation 897 is fin. the minimum value is 0.0
# * Generation 898 is fin. the minimum value is 0.0
# * Generation 899 is fin. the minimum value is 0.0
# * Generation 900 is fin. the minimum value is 0.0
# * Generation 901 is fin. the minimum value is 0.0
# * Generation 902 is fin. the minimum value is 0.0
# * Generation 903 is fin. the minimum value is 0.0
# * Generation 904 is fin. the minimum value is 0.0
# * Generation 905 is fin. the minimum value is 0.0
# * Generation 906 is fin. the minimum value is 0.0
# * Generation 907 is fin. the minimum value is 0.0
# * Generation 908 is fin. the minimum value is 0.0
# * Generation 909 is fin. the minimum value is 0.0
# * Generation 910 is fin. the minimum value is 0.0
# * Generation 911 is fin. the minimum value is 0.0
# * Generation 912 is fin. the minimum value is 0.0
# * Generation 913 is fin. the minimum value is 0.0
# * Generation 914 is fin. the minimum value is 0.0
# * Generation 915 is fin. the minimum value is 0.0
# * Generation 916 is fin. the minimum value is 0.0
# * Generation 917 is fin. the minimum value is 0.0
# * Generation 918 is fin. the minimum value is 0.0
# * Generation 919 is fin. the minimum value is 0.0
# * Generation 920 is fin. the minimum value is 0.0
# * Generation 921 is fin. the minimum value is 0.0
# * Generation 922 is fin. the minimum value is 0.0
# * Generation 923 is fin. the minimum value is 0.0
# * Generation 924 is fin. the minimum value is 0.0
# * Generation 925 is fin. the minimum value is 0.0
# * Generation 926 is fin. the minimum value is 0.0
# * Generation 927 is fin. the minimum value is 0.0
# * Generation 928 is fin. the minimum value is 0.0
# * Generation 929 is fin. the minimum value is 0.0
# * Generation 930 is fin. the minimum value is 0.0
# * Generation 931 is fin. the minimum value is 0.0
# * Generation 932 is fin. the minimum value is 0.0
# * Generation 933 is fin. the minimum value is 0.0
# * Generation 934 is fin. the minimum value is 0.0
# * Generation 935 is fin. the minimum value is 0.0
# * Generation 936 is fin. the minimum value is 0.0
# * Generation 937 is fin. the minimum value is 0.0
# * Generation 938 is fin. the minimum value is 0.0
# * Generation 939 is fin. the minimum value is 0.0
# * Generation 940 is fin. the minimum value is 0.0
# * Generation 941 is fin. the minimum value is 0.0
# * Generation 942 is fin. the minimum value is 0.0
# * Generation 943 is fin. the minimum value is 0.0
# * Generation 944 is fin. the minimum value is 0.0
# * Generation 945 is fin. the minimum value is 0.0
# * Generation 946 is fin. the minimum value is 0.0
# * Generation 947 is fin. the minimum value is 0.0
# * Generation 948 is fin. the minimum value is 0.0
# * Generation 949 is fin. the minimum value is 0.0
# * Generation 950 is fin. the minimum value is 0.0
# * Generation 951 is fin. the minimum value is 0.0
# * Generation 952 is fin. the minimum value is 0.0
# * Generation 953 is fin. the minimum value is 0.0
# * Generation 954 is fin. the minimum value is 0.0
# * Generation 955 is fin. the minimum value is 0.0
# * Generation 956 is fin. the minimum value is 0.0
# * Generation 957 is fin. the minimum value is 0.0
# * Generation 958 is fin. the minimum value is 0.0
# * Generation 959 is fin. the minimum value is 0.0
# * Generation 960 is fin. the minimum value is 0.0
# * Generation 961 is fin. the minimum value is 0.0
# * Generation 962 is fin. the minimum value is 0.0
# * Generation 963 is fin. the minimum value is 0.0
# * Generation 964 is fin. the minimum value is 0.0
# * Generation 965 is fin. the minimum value is 0.0
# * Generation 966 is fin. the minimum value is 0.0
# * Generation 967 is fin. the minimum value is 0.0
# * Generation 968 is fin. the minimum value is 0.0
# * Generation 969 is fin. the minimum value is 0.0
# * Generation 970 is fin. the minimum value is 0.0
# * Generation 971 is fin. the minimum value is 0.0
# * Generation 972 is fin. the minimum value is 0.0
# * Generation 973 is fin. the minimum value is 0.0
# * Generation 974 is fin. the minimum value is 0.0
# * Generation 975 is fin. the minimum value is 0.0
# * Generation 976 is fin. the minimum value is 0.0
# * Generation 977 is fin. the minimum value is 0.0
# * Generation 978 is fin. the minimum value is 0.0
# * Generation 979 is fin. the minimum value is 0.0
# * Generation 980 is fin. the minimum value is 0.0
# * Generation 981 is fin. the minimum value is 0.0
# * Generation 982 is fin. the minimum value is 0.0
# * Generation 983 is fin. the minimum value is 0.0
# * Generation 984 is fin. the minimum value is 0.0
# * Generation 985 is fin. the minimum value is 0.0
# * Generation 986 is fin. the minimum value is 0.0
# * Generation 987 is fin. the minimum value is 0.0
# * Generation 988 is fin. the minimum value is 0.0
# * Generation 989 is fin. the minimum value is 0.0
# * Generation 990 is fin. the minimum value is 0.0
# * Generation 991 is fin. the minimum value is 0.0
# * Generation 992 is fin. the minimum value is 0.0
# * Generation 993 is fin. the minimum value is 0.0
# * Generation 994 is fin. the minimum value is 0.0
# * Generation 995 is fin. the minimum value is 0.0
# * Generation 996 is fin. the minimum value is 0.0
# * Generation 997 is fin. the minimum value is 0.0
# * Generation 998 is fin. the minimum value is 0.0
# * Generation 999 is fin. the minimum value is 0.0
# * Generation 1000 is fin. the minimum value is 0.0

# %%
# %matplotlib inline

fig, ax = plt.subplots()
ax.set_title('Ackley function (n=10)')
ax.plot(generation, stats_min, label="best")
ax.plot(generation, stats_ave, label="average")
ax.plot(generation, stats_max, label="worst")
ax.set_xlabel('Generation')
ax.set_ylabel('Value')
ax.set_yscale('log')
ax.grid(which='both', color='lightgrey')
ax.legend()

# %% [markdown]
# ## Rosenbrock function

# %%
GEN = 100
N_DIM = 2
G_MIN = -5
G_MAX = 5
POP_SIZE = 300
PARENT_NUM = 50
CHILD_NUM = 200

EVALTYPE = alternation.evalType.MINIMIZE
CROSSTYPE = crossover.crossoverType.E_UNDX
RANDOMTYPE = crossover.randomType.UNIFORM

# %%
# object for JGG alternation
pop = alternation.JGG(dim=N_DIM,
                      evaluation_func=rosenbrock, evaluation_type=EVALTYPE,
                      gene_min=G_MIN, gene_max=G_MAX,
                      crossover_type=CROSSTYPE,
                      random_type=RANDOMTYPE,
                      pop_size=POP_SIZE, parent_num=PARENT_NUM, child_num=CHILD_NUM,
                      seed=64)

# make initial population
pop.init_population()

# evaluate initial population
pop.eval()

# %%
# %matplotlib nbagg

fig, ax = plt.subplots()

ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_xlim(-5, 5)
ax.set_ylim(-5, 5)
ax.grid(which='both', color='lightgrey')
artists = []

generation = []
stats_min = []
stats_max = []
stats_ave = []

generation.append(0)
stats_min.append(numpy.min([ind.fitness for ind in pop.population]))
stats_max.append(numpy.max([ind.fitness for ind in pop.population]))
stats_ave.append(numpy.average([ind.fitness for ind in pop.population]))

_tmp = numpy.array(pop.population)
im = ax.scatter(_tmp[:,0], _tmp[:,1], s=10)
artists.append([im])

for i in range(GEN):
    pop.generation_step()
    
    generation.append(i+1)
    stats_min.append(numpy.min([ind.fitness for ind in pop.population]))
    stats_max.append(numpy.max([ind.fitness for ind in pop.population]))
    stats_ave.append(numpy.average([ind.fitness for ind in pop.population]))
    
    if (i+1) % 10 == 0:
        _tmp = numpy.array(pop.population)
        im = ax.scatter(_tmp[:,0], _tmp[:,1], s=10)
        artists.append([im])

anim = ArtistAnimation(fig, artists, interval=1000)
anim.save('rosenbrock_test.gif', writer='imagemagick', fps=4)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline

fig, ax = plt.subplots()
ax.set_title('Rosenbrock function (n=2)')
ax.plot(generation, stats_min, label="best")
ax.plot(generation, stats_ave, label="average")
ax.plot(generation, stats_max, label="worst")
ax.set_xlabel('Generation')
ax.set_ylabel('Value')
ax.set_yscale('log')
ax.grid(which='both', color='lightgrey')
ax.legend()
